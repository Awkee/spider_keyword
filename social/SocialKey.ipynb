# %% [markdown]
# # 使用说明
#
# ## 依赖安装
#
# Python代码依赖库在使用前安装:
# ```sh
# pip install -r ./requirements.txt
# ```
#
# ## Cookie设置
#
# 使用前要使用浏览器访问weibo获取一条cookie填写进去，其实如果使用无头浏览器访问自动访问一次获取`cookie`后自动设置也是可以的，但是这样这个代码依赖就会多一些。
#
#
# ## Mongodb的用户权限设置方法：
#
# **新建用户:**
#
# ```sql
# use keywords
# db.createUser(
#   {
#     user: "myTestUser",
#     pwd:  passwordPrompt(),   // or cleartext password
#     roles:  [{ role: "readWrite", db: "keywords"}]
#   }
# )
# ```

# %%
import requests
from lxml import etree
from datetime import datetime
from parsel import Selector
import re
from pymongo import MongoClient


HEADERS_PC = {
    'User-Agent': 'Mozilla/5.0 (Windows x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
}
# MongoDB config
DEFAULT_MONGO_URI = 'mongodb://myTestUser:abcd1234@localhost:27017/keywords'
DEFAULT_WEIBO_COOKIE = 'SUB=_2AkMoGCnzf8NxqwJRmf8QzWjkbol3zgzEieKeRNgoJRMxHRl-yT9jqkM5tRB6A5gHHGlll66nBhQKS-cig_GPibaICo5Z; SUBP=0033WrSXqPxfM72-Ws9jqgMF55529P9D9WF70N0ypJucppYCyTVSmvZo; login_sid_t=72d0d19dda405cc237b42b6d95b256c3; cross_origin_proto=SSL; _s_tentry=passport.weibo.com; Apache=1136604738481.4927.1598334665588; SINAGLOBAL=1136604738481.4927.1598334665588; ULV=1598334665592:1:1:1:1136604738481.4927.1598334665588:; TC-Page-G0=62b98c0fc3e291bc0c7511933c1b13ad|1598335214|1598335126'

class SocialKey(object):
    '''
    社会热点关键词爬取
    '''
    def __init__(self, mongo_uri=DEFAULT_MONGO_URI, db='keywords', coll='social'):
        '''初始化信息'''
        self.keyword_list = []
        self.timestamp = datetime.timestamp(datetime.now())
        self.key_list = ['rank', 'keyword', 'platform', 'type', 'timestamp']
        self.mongo_uri = mongo_uri
        self.mongo_db = db
        self.mongo_coll = coll
        self.client = MongoClient(self.mongo_uri)
        self.db = self.client[self.mongo_db]
        self.doc = self.db[self.mongo_coll]
        self.cookie_weibo = DEFAULT_WEIBO_COOKIE

    def add_item(self, rank, keyword, platform, ptype, timestamp=None):
        item = {}
        if timestamp is None:
            timestamp = self.timestamp
        item['rank'] = rank
        item['keyword'] = keyword
        item['platform'] = platform
        item['type'] = ptype
        item['timestamp'] = timestamp
        self.keyword_list.append(item)

    def get_headers(self, ptype=None):
        '''获取Headers字典'''
        headers = HEADERS_PC
        if ptype == 'weibo':
            headers['referrer'] = "https://weibo.com/"
            headers['authority'] = 'weibo.com'
            headers['cookie'] = self.cookie_weibo
        return headers

    def social_key_baidu(self):
        '''百度热搜关键词'''
        url = 'http://top.baidu.com/buzz?b=1'
        resp = requests.get(url, headers=self.get_headers())
        doc = etree.HTML(resp.content.decode('gb2312'))
        tr_list = doc.xpath(r'//*[@id="main"]/div[2]/div/table/tr[not(contains(@class, "item-tr"))]')
        for tr in tr_list[1:]:
            td_list = tr.xpath('./td')
            nid = td_list[0].xpath('string(.)').strip()
            key = td_list[1].xpath('string(./a[@class="list-title"])').strip()
            score = td_list[3].xpath('string(.)').strip()
            self.add_item(nid, key, 'baidu', 'social')

    def social_key_weibo_hot_topic(self):
        '''微博热搜话题榜'''
        headers = self.get_headers('weibo')
        url_home = 'https://d.weibo.com/231650'
        for page in range(1,6):
            url = f'{url_home}??cfs=920&Pl_Discover_Pt6Rank__3_filter=&Pl_Discover_Pt6Rank__3_page={page}' 
            resp = requests.get(url, headers = headers)
            res_list = re.findall(r'"html":"(.*)"}\)</script>', resp.text)
            result = res_list[-1]

            a_list = re.sub(r'<.*?>|\\r|\\n|\\t|上一页|下一页|TOP', '' , result)
            a_list = re.sub('\s*?主持人', ',主持人', a_list)
            a_list = a_list.split()[0:-1]
            items = re.findall(r'([0-9]*?)(#.*?#).*阅读数:(.*(?:万|亿))?(?:,主持人:)?(.*)?', '\n'.join(a_list))
            for item in items:
                nid = int(item[0])
                key = item[1]
                self.add_item(nid, key, 'weibo', 'social')

    def social_key_weibo_hot_realtime(self):
        '''微博热搜榜'''
        headers = self.get_headers('weibo')

        url='https://s.weibo.com/top/summary?cate=realtimehot'
        resp = requests.get(url, headers = headers)
        selector = Selector(resp.text)
        tr_list = selector.xpath('//div[@id="pl_top_realtimehot"]/table/tbody/tr')
        for tr in tr_list[1:]:
            rank = tr.xpath('./td[1]/text()').get()
            hotword = tr.xpath('./td[2]/a/text()').get()
            search_num = tr.xpath('./td[2]/span/text()').get()
            self.add_item(rank, hotword, 'weibo', 'social')

    def save_to_mongo(self):
        '''数据保存到MongoDB'''
        return self.doc.insert_many(self.keyword_list)
    
    def process(self):
        '''任务处理'''
        self.social_key_baidu()
        self.social_key_weibo_hot_realtime()
        self.save_to_mongo()

    def show_keyword(self):
        for key in self.keyword_list:
            print(key)

if __name__ == '__main__':
    social_key = SocialKey()
    social_key.process()
    social_key.show_keyword()
# Out:
# {'rank': '1', 'keyword': '踹伤猥亵男男生被解除刑拘', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ad')}
# {'rank': '2', 'keyword': '美国威斯康星州进入紧急状态', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ae')}
# {'rank': '3', 'keyword': '巴威或成史上最强登陆东北台风', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311af')}
# {'rank': '4', 'keyword': '怀孕女子回娘家途中失联10年', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b0')}
# {'rank': '5', 'keyword': '郑爽前男友公司成被执行人', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b1')}
# {'rank': '6', 'keyword': '黎姿晒12位荧幕情人', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b2')}
# {'rank': '7', 'keyword': '特朗普宣布特赦银行抢劫犯', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b3')}
# {'rank': '8', 'keyword': '韩国13万名医生罢工3天', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b4')}
# {'rank': '9', 'keyword': '荷兰比利时均现二次感染新冠病例', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b5')}
# {'rank': '10', 'keyword': '特朗普子女盛赞他让美国再次伟大', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b6')}
# {'rank': '11', 'keyword': '吉林租房即可申请落户', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b7')}
# {'rank': '12', 'keyword': '舟山2死1伤案女伤者发声', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b8')}
# {'rank': '13', 'keyword': '新冠疫苗鼻腔滴入可起到免疫效果', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311b9')}
# {'rank': '14', 'keyword': '歌手李佳薇兼职房产中介', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ba')}
# {'rank': '15', 'keyword': '福建一退休干部组织百名女子卖淫', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311bb')}
# {'rank': '16', 'keyword': '香港发生大劫案', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311bc')}
# {'rank': '17', 'keyword': '爸爸要求儿子每天户外玩2小时', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311bd')}
# {'rank': '18', 'keyword': '应采儿生二胎的原因', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311be')}
# {'rank': '19', 'keyword': '造谣者向李冰冰及男友公开道歉', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311bf')}
# {'rank': '20', 'keyword': '保姆遭训斥后连扇男婴5个耳光', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c0')}
# {'rank': '21', 'keyword': '海底捞上半年净亏损9.65亿元', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c1')}
# {'rank': '22', 'keyword': '孟晚舟请求公开更多机密文件被否', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c2')}
# {'rank': '23', 'keyword': '宋丹丹60岁生日宴众星云集', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c3')}
# {'rank': '24', 'keyword': '香港立法会两反对派议员被捕', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c4')}
# {'rank': '25', 'keyword': '联合国拒绝美要求恢复制裁伊朗', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c5')}
# {'rank': '26', 'keyword': '新疆连续10天0新增', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c6')}
# {'rank': '27', 'keyword': '80后外卖小哥离世捐献器官救6人', 'platform': 'baidu', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c7')}
# {'rank': '1', 'keyword': '巩俐身材', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c8')}
# {'rank': '2', 'keyword': '美国开学仅一周多所高校新冠病例激增', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311c9')}
# {'rank': '3', 'keyword': '日常不寻常', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ca')}
# {'rank': '4', 'keyword': '齐明月才是迷惑行为大赏', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311cb')}
# {'rank': '5', 'keyword': 'body shame', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311cc')}
# {'rank': '6', 'keyword': '宋茜 年龄自定义', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311cd')}
# {'rank': '7', 'keyword': '谭松韵玻璃糖纸公主裙', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ce')}
# {'rank': '8', 'keyword': '海底捞上半年净亏损9.65亿元', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311cf')}
# {'rank': '9', 'keyword': '的哥凌晨跳河救人被冲走', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d0')}
# {'rank': '10', 'keyword': '香港反对派议员林卓廷及许智峰被捕', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d1')}
# {'rank': '11', 'keyword': '周震南左手牵右手', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d2')}
# {'rank': '12', 'keyword': '踹伤猥亵男男生被解除刑拘', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d3')}
# {'rank': '13', 'keyword': '郑爽直播状态', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d4')}
# {'rank': '14', 'keyword': '被手工耿开心挠挠椅卡住头发', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d5')}
# {'rank': '15', 'keyword': '这一年真的已经深刻改变了我', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d6')}
# {'rank': '16', 'keyword': '梅西将离开巴萨', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d7')}
# {'rank': '17', 'keyword': '清华研究生开学典礼', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d8')}
# {'rank': '18', 'keyword': '许凯重开电影院', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311d9')}
# {'rank': '19', 'keyword': '吉林租房居住即可申请落户', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311da')}
# {'rank': '20', 'keyword': '豆瓣崩了', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311db')}
# {'rank': '21', 'keyword': '青岛暴雨', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311dc')}
# {'rank': '22', 'keyword': '李佳薇做房产中介', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311dd')}
# {'rank': '23', 'keyword': '广东购买43种退热类药需实名登记', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311de')}
# {'rank': '24', 'keyword': 'A股', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311df')}
# {'rank': '25', 'keyword': '密室大逃脱', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e0')}
# {'rank': '26', 'keyword': '我和我的家乡回乡之路阵容', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e1')}
# {'rank': '27', 'keyword': '钟楚曦雨中跳舞', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e2')}
# {'rank': '28', 'keyword': '伊能静说阿朵是乘风破浪的精神之一', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e3')}
# {'rank': '29', 'keyword': '布雷克', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e4')}
# {'rank': '30', 'keyword': '美国威斯康星州进入紧急状态', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e5')}
# {'rank': '31', 'keyword': '北京新冠肺炎在院确诊病例全部清零', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e6')}
# {'rank': '32', 'keyword': '成毅黑白默系大片', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e7')}
# {'rank': '33', 'keyword': '跟着贾玲学撩汉', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e8')}
# {'rank': '34', 'keyword': '40年后再从深圳国贸大厦远眺', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311e9')}
# {'rank': '35', 'keyword': '联合国拒绝美要求恢复制裁伊朗', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ea')}
# {'rank': '36', 'keyword': '沈阳台风', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311eb')}
# {'rank': '37', 'keyword': '张新成哭戏绝了', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ec')}
# {'rank': '38', 'keyword': '宋丹丹60岁生日宴', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ed')}
# {'rank': '39', 'keyword': '上海地铁', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ee')}
# {'rank': '40', 'keyword': '以家人之名竖屏', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311ef')}
# {'rank': '41', 'keyword': '用AI让兵马俑动起来', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f0')}
# {'rank': '42', 'keyword': '贺子秋贺梅见面好虐', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f1')}
# {'rank': '43', 'keyword': '诺安', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f2')}
# {'rank': '44', 'keyword': '台风巴威北上辽宁', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f3')}
# {'rank': '45', 'keyword': '集美大桥', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f4')}
# {'rank': '46', 'keyword': '职工医保门诊费用拟纳入报销', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f5')}
# {'rank': '47', 'keyword': '利拉德将缺席G5', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f6')}
# {'rank': '48', 'keyword': '丽江被抱走3岁男孩父亲跪谢警察', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f7')}
# {'rank': '49', 'keyword': '以家人之名', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f8')}
# {'rank': '50', 'keyword': '学校复学成美国下一阶段疫情防控挑战', 'platform': 'weibo', 'type': 'social', 'timestamp': 1598419154.54213, '_id': ObjectId('5f45f0d2b8042f2c594311f9')}
